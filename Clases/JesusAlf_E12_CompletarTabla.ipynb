# %% [markdown]
# #**Jesus Romero Alfaro**
#
# ##Ejercicio 12
#
# ---
#
# Completar la tabla

# %%
from tabulate import tabulate 
datos=[["Pkt","Tpll","tps","Tiempo\narribo","Inicio\nservicio","Hora\nsalida","Tiempo\nen fila","Tiempo\nen sistema ","Tamaño\ncola","Numero\nclientes"],["1","2","12","2","2","14","0","12","0","4"],
      ["2","5","10","7","14","24","7","17","1","6"],
      ["3","1","16","8","24","40","16","32","2","7"],
      ["4","4","9","12","40","49","28","37","3","6"],
      ["5","1","10","13","49","59","36","46","4","5"],
      ["6","3","13","16","59","72","43","56","5","4"],
      ["7","3","17","19","72","89","53","70","6","3"],
      ["8","2","10","21","89","99","68","78","7","2"],
      ["9","4","8","25","99","107","74","82","8","1"],
      ["10","5","12","30","107","119","77","89","9","0"],]
print(tabulate(datos,headers="firstrow",tablefmt="grid",numalign="center"))
# Out:
# +-------+--------+-------+----------+------------+----------+-----------+---------------+----------+------------+
# |  Pkt  |  Tpll  |  tps  |  Tiempo  |   Inicio   |   Hora   |  Tiempo   |    Tiempo     |  Tamaño  |   Numero   |
# |       |        |       |  arribo  |  servicio  |  salida  |  en fila  |  en sistema   |   cola   |  clientes  |
# +=======+========+=======+==========+============+==========+===========+===============+==========+============+
# |   1   |   2    |  12   |    2     |     2      |    14    |     0     |      12       |    0     |     4      |
# +-------+--------+-------+----------+------------+----------+-----------+---------------+----------+------------+
# |   2   |   5    |  10   |    7     |     14     |    24    |     7     |      17       |    1     |     6      |
# +-------+--------+-------+----------+------------+----------+-----------+---------------+----------+------------+
# ...

# %% [markdown]
# $\lambda=\frac{10}{28}=0.33$ , $\mu=\frac{10}{117}=0.085$ , $Wq=\frac{402}{10}=40.2$ , $W=\frac{519}{10}=51.9$ , $Lq=Wq*\lambda=13.266$ , $L=W*\lambda=17.127$
